# %% [markdown]
# # E quando o nosso código demora muito? Será que travou? Quanto tempo vai demorar?
#
# ### Biblioteca/Módulo tqdm
#
# - Vamos importar os arquivos csv da Empresa Contoso e tratar como fizemos ao longo desse módulo

# %%
import pandas as pd
#importando os arquivos
vendas_df = pd.read_csv(r'Contoso - Vendas - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv(r'Contoso - Lojas.csv', sep=';')
clientes_df = pd.read_csv(r'Contoso - Clientes.csv', sep=';')

#limpando apenas as colunas que queremos
clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome do Produto']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]

#mesclando e renomeando os dataframes
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente').rename(columns={'E-mail': 'E-mail do Cliente'})
# Out:
# 100%|██████████████████████████████████████████████████████████████████████| 980642/980642 [00:15<00:00, 228163.90it/s]
#     Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                 1    01/01/2017    02/01/2017         1       86
# 1                 2    01/01/2017    06/01/2017         5      308
# 2                 3    01/01/2017    01/01/2017         0      294
# 3                 4    01/01/2017    01/01/2017         0      251
# 4                 5    01/01/2017    07/01/2017         6       94
# ..              ...           ...           ...       ...      ...
# 95               96    01/01/2017    09/01/2017         8      310
# 96               97    01/01/2017    01/01/2017         0      310
# 97               98    01/01/2017    09/01/2017         8      307
# 98               99    01/01/2017    03/01/2017         2      306
# 99              100    01/01/2017    05/01/2017         4      249
#
#     ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0          981            2        6825                   9
# 1         1586            2       18469                   9
# 2         1444            5       19730                  13
# 3         1468            5       29326                   6
# 4         1106            2       22617                   4
# ..         ...          ...         ...                 ...
# 95        1250            5        8731                   6
# 96         513            5       22532                   6
# 97         796            5       36137                   6
# 98        1269           10       26238                   8
# 99        1041           10        5655                   8
#
#     Quantidade Devolvida                                    Nome do Produto  \
# 0                      1         A. Datum Advanced Digital Camera M300 Pink
# 1                      1              SV DVD 55DVD Storage Binder M56 Black
# 2                      1  The Phone Company Touch Screen Phones 26-2.2" ...
# 3                      1        Contoso Touch Screen Phones - CRT M11 Black
# 4                      1                     Contoso SLR Camera M146 Orange
# ..                   ...                                                ...
# 95                     0  Contoso Travel Charger for S-Series Battery E3...
# 96                     0                   Adventure Works LCD15 E100 White
# 97                     0  Contoso USB Data Link - direct connect adapter...
# 98                     0                    Contoso Carrying Case E312 Blue
# 99                     0      A. Datum Full Frame Digital Camera X300 Azure
#
#                            Nome da Loja               E-mail do Cliente
# 0                  Loja Contoso Austin           rbrumfieldmy@ameblo.jp
# 1   Loja Contoso North America Reseller          cshawd4@technorati.com
# 2             Loja Contoso Tehran No.2           kgorriekd@bandcamp.com
# 3               Loja Contoso Singapore     angela49@adventure-works.com
# 4           Loja Contoso Grand Prairie       jacob4@adventure-works.com
# ..                                  ...                             ...
# 95           Loja Contoso Asia Reseller               mkernellkc@pen.io
# 96           Loja Contoso Asia Reseller  benjamin30@adventure-works.com
# 97            Loja Contoso Asia Online     kaitlyn6@adventure-works.com
# 98          Loja Contoso Europe Online     edward17@adventure-works.com
# 99                 Loja Contoso Dublin        cjanouseki8@rakuten.co.jp
#
# [100 rows x 13 columns]

# %% [markdown]
# ### Agora, imagina que a Loja Contoso Roma (ID 222), para tentar burlar o sistema de metas, diminuiu 1 da quantidade devolvida de todas as vendas que ela teve. Descobrindo isso, precisamos ajeitar a base
#
# - Farei com um for, principalmente por motivos didáticos, mas teríamos outras formas de fazer isso também.

# %%
from tqdm import tqdm
tqdm.pandas()
p_bar = tqdm(total = len(vendas_df['ID Loja']), position = 0, leave = True)
id_loja_roma = 222
for i, id_loja in enumerate(vendas_df['ID Loja']):
    p_bar.update()
    if id_loja == id_loja_roma:
        vendas_df.loc[i, 'Quantidade Devolvida'] += 1


loja_roma = vendas_df[vendas_df['ID Loja'] == 222]
display(loja_roma)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 980642/980642 [01:43<00:00, 9445.04it/s]
#  98%|████████████████████████████████████████████████████████████████████▉ | 965715/980642 [00:02<00:00, 232953.38it/s]
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 2553               2554    02/01/2017    02/01/2017         0      222
# 38921             38922    17/01/2017    17/01/2017         0      222
# 45155             45156    19/01/2017    19/01/2017         0      222
# 51117             51118    22/01/2017    29/01/2017         7      222
# 52480             52481    22/01/2017    22/01/2017         0      222
# ...                 ...           ...           ...       ...      ...
# 979149           979150    31/12/2017    31/12/2017         0      222
# 979160           979161    31/12/2017    31/12/2017         0      222
# 979472           979473    31/12/2017    31/12/2017         0      222
# 980394           980395    31/12/2017    01/01/2018         1      222
# 980595           980596    31/12/2017    31/12/2017         0      222
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 2553           390           10       12182                   8
# 38921          390           10        5801                   8
# 45155          352           10       37135                   4
# 51117          357           10       26699                   4
# 52480          382           10       16563                   8
# ...            ...          ...         ...                 ...
# 979149         229           10        7244                   4
# 979160         942           10       10431                   4
# 979472        1211           10       11010                   8
# 980394         817           10       30130                   4
# 980595        1521           10       24441                   8
#
#         Quantidade Devolvida  \
# 2553                       2
# 38921                      2
# 45155                      2
# 51117                      2
# 52480                      2
# ...                      ...
# 979149                     2
# 979160                     2
# 979472                     3
# 980394                     2
# 980595                     2
#
#                                           Nome do Produto        Nome da Loja  \
# 2553                            WWI Laptop19W X0196 Black  Loja Contoso Roma
# 38921                           WWI Laptop19W X0196 Black  Loja Contoso Roma
# 45155                     Fabrikam Laptop8.9 E0800 Silver  Loja Contoso Roma
# 51117                       Fabrikam Laptop14.1 E4101 Red  Loja Contoso Roma
# 52480                  Adventure Works Laptop12 M1201 Red  Loja Contoso Roma
# ...                                                   ...                 ...
# 979149  Litware Home Theater System 2.1 Channel E212 B...  Loja Contoso Roma
# 979160                 SV PCI Network Adapter E904 Silver  Loja Contoso Roma
# 979472  Fabrikam Business Videographer 2/3'' 17mm M280...  Loja Contoso Roma
# 980394  Contoso Power Inverter - DC to AC power invert...  Loja Contoso Roma
# 980595     The Phone Company PDA Wifi 3.7-inch M250 Black  Loja Contoso Roma
#
#                       E-mail do Cliente
# 2553      bwhyborne53@printfriendly.com
# 38921                kfiveyma@google.fr
# 45155   alexandra69@adventure-works.com
# 51117         juan9@adventure-works.com
# 52480                 cberrefp@hibu.com
# ...                                 ...
# 979149            wbisacre6t@devhub.com
# 979160           ksimonic0@berkeley.edu
# 979472             cvannb@csmonitor.com
# 980394   veronica20@adventure-works.com
# 980595       jose77@adventure-works.com
#
# [819 rows x 13 columns]
# 100%|██████████████████████████████████████████████████████████████████████| 980642/980642 [00:15<00:00, 232953.38it/s]

# %% [markdown]
# #
